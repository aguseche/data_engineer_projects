# %% [markdown]
# Since im uploading everythin into a Data Lake i will not make any Transformations into this data, this notebook is just for exploratory analysis

# %%
import pandas as pd

# %%
df_green = pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2022-01.parquet')
# df_yellow = pd.read_parquet('data/yellow_tripdata_2022-01.parquet')

# %%
df_green
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
df_green.info()
#Only 62k
#drop ehail_fee all nulls
#[Pickup, dropoff, LocationIDs, Trip, Fare, Extra, Tip, Tolls, improvement, total_amoun] -> no nulls
#Weird all the other tables have exactly 56200 [RatecodeID, passanger_count, payment_type, trip_type, congestion_surcharge]
#Maybe if it is a delivery (no passanger) it does not need those inputs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62495 entries, 0 to 62494
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   VendorID               62495 non-null  int64
#  1   lpep_pickup_datetime   62495 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  62495 non-null  datetime64[ns]
#  3   store_and_fwd_flag     56200 non-null  object
#  4   RatecodeID             56200 non-null  float64
#  5   PULocationID           62495 non-null  int64
#  6   DOLocationID           62495 non-null  int64
#  7   passenger_count        56200 non-null  float64
#  8   trip_distance          62495 non-null  float64
#  9   fare_amount            62495 non-null  float64
#  10  extra                  62495 non-null  float64
#  11  mta_tax                62495 non-null  float64
#  12  tip_amount             62495 non-null  float64
#  13  tolls_amount           62495 non-null  float64
# ...

# %%
df_green['trip_type'].unique()
# Out:
# array([ 1.,  2., nan])

# %%
df_yellow.info()
#Almost 2.5 million
#[passanger_count, RatecodeID, store_and_fwd_flag, congestion_surcharge] -> has 71503 nulls
#All the others no nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463931 entries, 0 to 2463930
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int64
#  1   tpep_pickup_datetime   datetime64[ns]
#  2   tpep_dropoff_datetime  datetime64[ns]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int64
#  8   DOLocationID           int64
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  airport_fee            float64
# dtypes: datetime64[ns](2), float64(12), int64(4), object(1)
# ...

# %%
df_yellow['airport_fee'].isnull().sum()
# Out:
# 71503
